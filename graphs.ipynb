# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,15,15)
allcolor = [0.328, 0.352, 0.376, 0.336, 0.336, 0.336, 0.334, 0.336, 0.312, 0.272, 0.272 ,0.272 ,0.272, 0.272, 0.272]
allsobel = [0.3680, 0.4, 0.36, 0.304, 0.328, 0.392, 0.384, 0.36, 0.328, 0.272, 0.272, 0.272, 0.272, 0.272, 0.272,]
example = [0.6416, 0.7559, 0.8243, 0.8588, 0.8860, 0.9023, 0.9201, 0.9275, 0.9321, 0.9408, 0.9461, 0.9474, 0.9521, 0.9553, 0.9598]

plt.plot(x,example, label = 'Example')
plt.plot(x,allcolor, label = 'Color')
plt.plot(x,allsobel, label = 'Sobel')
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')  
plt.legend()
plt.show()
